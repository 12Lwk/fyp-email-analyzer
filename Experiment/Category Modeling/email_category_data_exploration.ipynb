# %% [markdown]
# # Category Exploration

# %%
import pandas as pd

email_data = pd.read_csv('C:/Users/User/OneDrive - Asia Pacific University/APU Final Year Project/FYP Email Project Documents/Email Dataset Python/FYP PART 2/Category Modeling/final_email_category_balanced.csv')

# %%
email_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242379 entries, 0 to 242378
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   From              242379 non-null  object
#  1   To                235681 non-null  object
#  2   Subject           235589 non-null  object
#  3   Message           242378 non-null  object
#  4   Day               242379 non-null  object
#  5   Date & Time       242379 non-null  object
#  6   url_count         242379 non-null  int64
#  7   Cleaned_Subject   227561 non-null  object
#  8   Cleaned_Message   241774 non-null  object
#  9   Combined_Text     242379 non-null  object
#  10  Qwen2.5_Category  242379 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 20.3+ MB

# %%
email_data['Qwen2.5_Category'].value_counts()
# Out:
# Qwen2.5_Category
# General Business Communication              55924
# Finance & Transactions                      35682
# Personal Communication & Purely Personal    29053
# Meeting & Scheduling                        21720
# IT Alerts & System Notifications            20000
# Spam                                        20000
# Legal & Contractual                         20000
# Project Management & Strategy               20000
# Internal Policies & HR Updates              20000
# Name: count, dtype: int64

# %%
## General Business Communication

import matplotlib.pyplot as plt
from wordcloud import WordCloud

business_emails = email_data[email_data['Qwen2.5_Category'] == 'General Business Communication']
text = " ".join(str(msg) for msg in business_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for General Business Communication Emails")
plt.show()

## Finance & Transactions

finance_emails = email_data[email_data['Qwen2.5_Category'] == 'Finance & Transactions']
text = " ".join(str(msg) for msg in finance_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Finance & Transactions Emails")
plt.show()

## Personal Communication & Purely Personal 

personal_emails = email_data[email_data['Qwen2.5_Category'] == 'Personal Communication & Purely Personal']
text = " ".join(str(msg) for msg in personal_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Personal Communication & Purely Personal Emails")
plt.show()

## Meeting & Scheduling  

meeting_emails = email_data[email_data['Qwen2.5_Category'] == 'Meeting & Scheduling']
text = " ".join(str(msg) for msg in meeting_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Meeting & Scheduling Emails")
plt.show()

## IT Alerts & System Notifications 

IT_emails = email_data[email_data['Qwen2.5_Category'] == 'IT Alerts & System Notifications']
text = " ".join(str(msg) for msg in IT_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for IT Alerts & System Notifications Emails")
plt.show()

## Project Management & Strategy

project_emails = email_data[email_data['Qwen2.5_Category'] == 'Project Management & Strategy']
text = " ".join(str(msg) for msg in project_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Project Management & Strategy Emails")
plt.show()

## Legal & Contractual

legal_emails = email_data[email_data['Qwen2.5_Category'] == 'Legal & Contractual']
text = " ".join(str(msg) for msg in legal_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Legal & Contractual Emails")
plt.show()

## Internal Policies & HR Updates

hr_emails = email_data[email_data['Qwen2.5_Category'] == 'Internal Policies & HR Updates']
text = " ".join(str(msg) for msg in hr_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Internal Policies & HR Updates Emails")
plt.show()

## Spam

spam_emails = email_data[email_data['Qwen2.5_Category'] == 'Spam']
text = " ".join(str(msg) for msg in spam_emails['Cleaned_Message'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Spam Emails")
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

categories = email_data['Qwen2.5_Category'].unique()

for category in categories:
    category_emails = email_data[email_data['Qwen2.5_Category'] == category]
    
    text = " ".join(str(msg) for msg in category_emails['Cleaned_Message'].dropna())
    words = text.split()
    
    word_freq = Counter(words)
    top_words = word_freq.most_common(20)
    
    if not top_words:
        continue

    labels, values = zip(*top_words)

    plt.figure(figsize=(12, 6))
    plt.barh(labels, values)
    plt.xlabel("Frequency")
    plt.title(f"Top 20 Words in '{category}' Emails")
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()

# %%
email_data['Cleaned_Message'] = email_data['Cleaned_Message'].fillna("")
email_data['Text_Length'] = email_data['Cleaned_Message'].apply(len)

print("Text Length Statistics:")
print(email_data['Text_Length'].describe())
# Out:
# Text Length Statistics:
# count    242379.000000
# mean        137.578289
# std         129.469423
# min           0.000000
# 25%          26.000000
# 50%          94.000000
# 75%         221.000000
# max         500.000000
# Name: Text_Length, dtype: float64

# %%
#Log Transformation
import numpy as np

email_data['Log_Body_Length'] = np.log1p(email_data['Text_Length'])  # log(1 + x) to handle 0s

print(email_data[['Text_Length', 'Log_Body_Length']].head())

email_data['Log_Body_Length'].hist(bins=50, figsize=(8, 6))
plt.title('Log-Transformed Text Length Distribution')
plt.xlabel('Log Body Length')
plt.ylabel('Frequency')
plt.show()
# Out:
#    Text_Length  Log_Body_Length
# 0          452         6.115892
# 1          452         6.115892
# 2          452         6.115892
# 3          452         6.115892
# 4           95         4.564348

# %%
#Scaling (Min-Max Scaling)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

email_data['Scaled_Body_Length'] = scaler.fit_transform(email_data[['Text_Length']])

print(email_data[['Text_Length', 'Scaled_Body_Length']].head())

email_data['Scaled_Body_Length'].hist(bins=50, figsize=(8, 6))
plt.title('Min-Max Scaled Text Length Distribution')
plt.xlabel('Scaled Body Length')
plt.ylabel('Frequency')
plt.show()
# Out:
#    Text_Length  Scaled_Body_Length
# 0          452               0.904
# 1          452               0.904
# 2          452               0.904
# 3          452               0.904
# 4           95               0.190

# %%
#Standardization (Z-Score)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

email_data['Standardized_Body_Length'] = scaler.fit_transform(email_data[['Text_Length']])

print(email_data[['Text_Length', 'Standardized_Body_Length']].head())

email_data['Standardized_Body_Length'].hist(bins=50, figsize=(8, 6))
plt.title('Standardized Text Length Distribution')
plt.xlabel('Standardized Body Length')
plt.ylabel('Frequency')
plt.show()
# Out:
#    Text_Length  Standardized_Body_Length
# 0          452                  2.428545
# 1          452                  2.428545
# 2          452                  2.428545
# 3          452                  2.428545
# 4           95                 -0.328868

# %%
email_data.columns
# Out:
# Index(['From', 'To', 'Subject', 'Message', 'Day', 'Date & Time', 'url_count',
#        'Cleaned_Subject', 'Cleaned_Message', 'Combined_Text',
#        'Qwen2.5_Category', 'Text_Length', 'Log_Body_Length',
#        'Scaled_Body_Length', 'Standardized_Body_Length'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Group and plot
avg_url_per_category = email_data.groupby('Qwen2.5_Category')['url_count'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
avg_url_per_category.plot(kind='bar', color='skyblue')
plt.ylabel('Average URL Count')
plt.title('Average URL Count by Email Category')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='Qwen2.5_Category', y='url_count', data=email_data)
plt.xticks(rotation=45, ha='right')
plt.title('URL Count Distribution by Email Category')
plt.tight_layout()
plt.show()

# %%
avg_url_per_category = email_data.groupby('Qwen2.5_Category')['url_count'].mean()
email_data['avg_url_category'] = email_data['Qwen2.5_Category'].map(avg_url_per_category)

# %%
email_data.columns
# Out:
# Index(['From', 'To', 'Subject', 'Message', 'Day', 'Date & Time', 'url_count',
#        'Cleaned_Subject', 'Cleaned_Message', 'Combined_Text',
#        'Qwen2.5_Category', 'Text_Length', 'Log_Body_Length',
#        'Scaled_Body_Length', 'Standardized_Body_Length', 'avg_url_category'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

df_copy = email_data.copy()

le = LabelEncoder()
df_copy['Category_Label'] = le.fit_transform(df_copy['Qwen2.5_Category'])

columns_to_exclude = [
    'From', 'To', 'Subject', 'Message', 'Day', 'Date & Time', 'url_count',
    'Cleaned_Subject', 'Cleaned_Message', 'Combined_Text', 'Qwen2.5_Category'
]
df_reduced = df_copy.drop(columns=columns_to_exclude, errors='ignore')

numeric_df = df_reduced.select_dtypes(include=['number'])

correlation_matrix = numeric_df.corr()

# Plot
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix (Including Encoded Target)')
plt.tight_layout()
plt.show()

# %%
email_data = email_data.drop(columns=['Text_Length', 'Scaled_Body_Length', 'Standardized_Body_Length'])

# %%
email_data.columns
# Out:
# Index(['From', 'To', 'Subject', 'Message', 'Day', 'Date & Time', 'url_count',
#        'Cleaned_Subject', 'Cleaned_Message', 'Combined_Text',
#        'Qwen2.5_Category', 'Log_Body_Length', 'avg_url_category'],
#       dtype='object')

# %%
email_data['Qwen2.5_Category'].value_counts()
# Out:
# Qwen2.5_Category
# General Business Communication              55924
# Finance & Transactions                      35682
# Personal Communication & Purely Personal    29053
# Meeting & Scheduling                        21720
# IT Alerts & System Notifications            20000
# Spam                                        20000
# Legal & Contractual                         20000
# Project Management & Strategy               20000
# Internal Policies & HR Updates              20000
# Name: count, dtype: int64

# %%
email_data.to_csv("final_email_category_balanced.csv", index=False)

# %%
email_data
