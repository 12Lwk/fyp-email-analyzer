# %%
import pandas as pd

email_data = pd.read_csv('C:/Users/User/OneDrive - Asia Pacific University/APU Final Year Project/FYP Email Project Documents/Email Dataset Python/FYP PART 2/Spam Data Preparation/mail_data.csv')

# %%
email_data.columns
# Out:
# Index(['Category', 'Message'], dtype='object')

# %%
total_rows, total_columns = email_data.shape
print(f"🧮 Total rows: {total_rows}")
print(f"🧾 Total columns: {total_columns}")
# Out:
# 🧮 Total rows: 5572
# 🧾 Total columns: 2

# %%
email_data['Category'].value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64
